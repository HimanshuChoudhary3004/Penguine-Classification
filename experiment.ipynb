# %%
from azureml.core import Workspace, Dataset

ws = Workspace.from_config('.azureml/')
# Out:
# Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception (azureml-dataprep 5.3.0 (e:\my projects\new project\venv\lib\site-packages), Requirement.parse('azureml-dataprep<5.2.0a,>=5.1.0a'), {'azureml-dataset-runtime'}).

# %%
from azureml.core import Dataset
dataset = Dataset.get_by_name(workspace=ws,name='penguine_iter')

# %%
import pandas as pd
print(pd.__version__)

df = dataset.to_pandas_dataframe()
# Out:
# 2.2.3
# {'infer_column_types': 'False', 'activity': 'to_pandas_dataframe'}
# {'infer_column_types': 'False', 'activity': 'to_pandas_dataframe', 'activityApp': 'TabularDataset'}

# %%
df.head()
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID  Clutch Completion Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               True      NaT
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               True      NaT
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               True      NaT
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               True      NaT
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               True      NaT
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 0                39.1               18.7                181.0         3750.0
# 1                39.5               17.4                186.0         3800.0
# 2                40.3               18.0                195.0         3250.0
# 3                 NaN                NaN                  NaN            NaN
# 4                36.7               19.3                193.0         3450.0
#
#       Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 0    MALE                NaN                NaN
# 1  FEMALE            8.94956          -24.69454
# 2  FEMALE            8.36821          -25.33302
# 3    None                NaN                NaN
# 4  FEMALE            8.76651          -25.32426
#
#                          Comments
# 0  Not enough blood for isotopes.
# 1                            None
# 2                            None
# 3              Adult not sampled.
# 4                            None
